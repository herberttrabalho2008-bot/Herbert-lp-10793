# %% [markdown]
# Aula 2 - o primeiro notebook

# %%
a=7
b=2
print(a+b, a/b, a-b, a*b, a // b, a%b, a==b)

# %% [markdown]
# # 1. Numa célula nova, escreve um programa que pede dois números e mostra a soma, a média e o maior deles.

# %%
a = float(input("Introduza um número: "))
b = float(input("Introduza um outro número: "))
print("Soma: ",a+b)
print("Média: ",(a+b)/2)
if(a>b):
    maior = a
else:
    maior=b
print("Maior: ", maior)

# %% [markdown]
# ## Continuação (antes em aulas/aula.ipynb)

# %%
a = 7
b = 2
print(a + b, a - b, a * b, a / b, a // b, a % b, a ** b)

# %%
num1 = input("Digite um número: ")
num2 = input("Digite outro número: ")
 
soma = int(num1) + int(num2)
media = soma / 2
maior = max(num1, num2)
 
print("A soma dos números é:", soma)
print("A média dos números é:", media)
print("O maior número é:", maior)

# %% [markdown]
# #Exercicio 1

# %%
a = 7 
b = 7.0 
c = "7" 
d = a == b 
print(type(a)) 
print(type(b)) 
print(type(c)) 
print(type(d)) 
print(a == b) 
print(a + b)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# True
# 14.0

# %% [markdown]
# #Exercicio 2

# %%
x = 10 
y = 3 
print(x > y) 
print(x == y) 
print(x != y) 
print(x / y == 3) 
print("Python" == "python") 
print(len("Python") == 6)
# Out:
# True
# False
# True
# False
# False
# True

# %% [markdown]
# #Exercicio 3

# %%
temperatura = int(input("Temperatura em graus: ")) 
if temperatura >=30: print("Está calor") 
elif temperatura >= 20: print("Está agradável") 
else: print("Está frio")
# Out:
# Está calor

# %% [markdown]
# #Exercicio 4

# %%
idade = 20 
tem_bilhete = True 
if idade >= 18 and tem_bilhete: print("Entrada permitida") 
else: print("Entrada recusada")
# Out:
# Entrada permitida

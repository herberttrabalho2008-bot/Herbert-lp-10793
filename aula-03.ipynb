# %%
#Exercicio 1

# %%
print(2 + 3 * 4)
print((2 + 3) * 4)
print(10 - 4 / 2)
print(2 ** 3 * 2)
print(17 // 5 + 17 % 5)
# Out:
# 14
# 20
# 8.0
# 16
# 5

# %%
#Exercício 2

# %%
preco_refeicao = 2.50
nome = input("Nome: ")
refeicoes = int (input("Quantas refeições? "))
total = refeicoes * preco_refeicao
print(f"{nome}, vais pagar {total:.2f} €.")
# Out:
# herbert, vais pagar 10.00 €.

# %%
#Exercício 3

# %%
min = int(input("Minutos: "))
horas = min // 60
minutos = min % 60
print(f"{horas} horas e {minutos} minutos.")
# Out:
# 4279 horas e 49 minutos.

# %%
#Exercício 4

# %%
# Soma de dois números inteiros
numero1 = int(input("Primeiro número: "))
numero2 = int(input("Segundo número: "))
soma = numero1 + numero2
print("Soma:", soma)
